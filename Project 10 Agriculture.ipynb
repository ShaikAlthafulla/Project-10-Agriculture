# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel (r'C:/Users/Althaf/Downloads/train_agriculture.xlsx')
df
# Out:
#              ID  Estimated_Insects_Count  Crop_Type  Soil_Type  \
# 0     F00000001                      188          1          0
# 1     F00000003                      209          1          0
# 2     F00000004                      257          1          0
# 3     F00000005                      257          1          1
# 4     F00000006                      342          1          0
# ...         ...                      ...        ...        ...
# 4594  F00008078                     2138          0          1
# 4595  F00008079                     2139          0          1
# 4596  F00008080                     2267          0          1
# 4597  F00008082                     2267          0          1
# 4598  F00008083                     2267          0          1
#
#       Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# 0                          1                  0                0.0
# 1                          1                  0                0.0
# ...

# %%
df.shape
# Out:
# (1199, 9)

# %%
df.columns
# Out:
# Index(['ID', 'Estimated_Insects_Count', 'Crop_Type', 'Soil_Type',
#        'Pesticide_Use_Category', 'Number_Doses_Week', 'Number_Weeks_Used',
#        'Number_Weeks_Quit', 'Season'],
#       dtype='object')

# %%
df.dtypes
# Out:
# ID                          object
# Estimated_Insects_Count      int64
# Crop_Type                    int64
# Soil_Type                    int64
# Pesticide_Use_Category       int64
# Number_Doses_Week            int64
# Number_Weeks_Used          float64
# Number_Weeks_Quit            int64
# Season                       int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1199 non-null   object
#  1   Estimated_Insects_Count  1199 non-null   int64
#  2   Crop_Type                1199 non-null   int64
#  3   Soil_Type                1199 non-null   int64
#  4   Pesticide_Use_Category   1199 non-null   int64
#  5   Number_Doses_Week        1199 non-null   int64
#  6   Number_Weeks_Used        1080 non-null   float64
#  7   Number_Weeks_Quit        1199 non-null   int64
#  8   Season                   1199 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 84.4+ KB

# %%
df.describe()
# Out:
#        Estimated_Insects_Count    Crop_Type    Soil_Type  \
# count              1199.000000  1199.000000  1199.000000
# mean               1288.737281     0.194329     0.455379
# std                 845.004912     0.395848     0.498213
# min                 150.000000     0.000000     0.000000
# 25%                 677.000000     0.000000     0.000000
# 50%                1056.000000     0.000000     0.000000
# 75%                1785.000000     0.000000     1.000000
# max                4097.000000     1.000000     1.000000
#
#        Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# count             1199.000000        1199.000000        1080.000000
# mean                 2.383653          26.555463          29.033333
# std                  0.522866          16.154101          12.782083
# min                  1.000000           0.000000           0.000000
# 25%                  2.000000          15.000000          20.000000
# ...

# %%
#lets check whether the null values are present in the dataset or not using heatmap
sns.heatmap(df.isnull(),annot=True)
plt.show()

# %%
#Lets check the null values without using visualization
df.isnull().sum()
# Out:
# ID                           0
# Estimated_Insects_Count      0
# Crop_Type                    0
# Soil_Type                    0
# Pesticide_Use_Category       0
# Number_Doses_Week            0
# Number_Weeks_Used          119
# Number_Weeks_Quit            0
# Season                       0
# dtype: int64

# %%
df.plot(kind='box',subplots=True,layout=(5,6))
# Out:
# Estimated_Insects_Count       AxesSubplot(0.125,0.749828;0.110714x0.130172)
# Crop_Type                  AxesSubplot(0.257857,0.749828;0.110714x0.130172)
# Soil_Type                  AxesSubplot(0.390714,0.749828;0.110714x0.130172)
# Pesticide_Use_Category     AxesSubplot(0.523571,0.749828;0.110714x0.130172)
# Number_Doses_Week          AxesSubplot(0.656429,0.749828;0.110714x0.130172)
# Number_Weeks_Used          AxesSubplot(0.789286,0.749828;0.110714x0.130172)
# Number_Weeks_Quit             AxesSubplot(0.125,0.593621;0.110714x0.130172)
# Season                     AxesSubplot(0.257857,0.593621;0.110714x0.130172)
# dtype: object

# %%
df.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DE0FC0188>,
# ...
#       dtype=object)

# %%
sns.pairplot(df)

# %%
#Lets check the correlation matrix
df.corr()
# Out:
#                          Estimated_Insects_Count  Crop_Type  Soil_Type  \
# Estimated_Insects_Count                 1.000000   0.020773  -0.339516
# Crop_Type                               0.020773   1.000000   0.063050
# Soil_Type                              -0.339516   0.063050   1.000000
# Pesticide_Use_Category                  0.038259   0.482378   0.129857
# Number_Doses_Week                      -0.121168  -0.170014   0.057118
# Number_Weeks_Used                       0.521308   0.065865  -0.146997
# Number_Weeks_Quit                       0.146441  -0.390935  -0.191989
# Season                                  0.023384   0.020282  -0.069242
#
#                          Pesticide_Use_Category  Number_Doses_Week  \
# Estimated_Insects_Count                0.038259          -0.121168
# Crop_Type                              0.482378          -0.170014
# Soil_Type                              0.129857           0.057118
# ...

# %%
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),cmap='Blues',annot=True)

# %%
#Lets describe the matrix
df.describe()
# Out:
#        Estimated_Insects_Count    Crop_Type    Soil_Type  \
# count              1199.000000  1199.000000  1199.000000
# mean               1288.737281     0.194329     0.455379
# std                 845.004912     0.395848     0.498213
# min                 150.000000     0.000000     0.000000
# 25%                 677.000000     0.000000     0.000000
# 50%                1056.000000     0.000000     0.000000
# 75%                1785.000000     0.000000     1.000000
# max                4097.000000     1.000000     1.000000
#
#        Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# count             1199.000000        1199.000000        1080.000000
# mean                 2.383653          26.555463          29.033333
# std                  0.522866          16.154101          12.782083
# min                  1.000000           0.000000           0.000000
# 25%                  2.000000          15.000000          20.000000
# ...

# %%
#Lets check the skewness of the dataset
df.skew()
#there is some skewness which needs to be treated ,by seeing we can say obly +ve skewness is signifiacnt and needs to be treated
# Out:
# Estimated_Insects_Count    1.098665
# Crop_Type                  1.546968
# Soil_Type                  0.179422
# Pesticide_Use_Category     0.089675
# Number_Doses_Week          0.872028
# Number_Weeks_Used          0.209152
# Number_Weeks_Quit          1.191013
# Season                     0.155872
# dtype: float64

# %%
df_train = pd.read_excel (r'C:/Users/Althaf/Downloads/test_agriculture.xlsx')
df_train
# Out:
#              ID  Estimated_Insects_Count  Crop_Type  Soil_Type  \
# 0     F00000002                      188          1          1
# 1     F00000007                      410          1          1
# 2     F00000011                      626          1          0
# 3     F00000013                      731          1          0
# 4     F00000014                      789          0          0
# ...         ...                      ...        ...        ...
# 1194  F00003133                     1132          0          1
# 1195  F00003135                     1132          0          1
# 1196  F00003138                     1132          0          1
# 1197  F00003149                     1212          0          1
# 1198  F00003150                     1212          0          1
#
#       Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# 0                          1                  0                NaN
# 1                          1                  0                0.0
# ...

# %%
df_train.shape
# Out:
# (1199, 9)

# %%
df_train.columns
# Out:
# Index(['ID', 'Estimated_Insects_Count', 'Crop_Type', 'Soil_Type',
#        'Pesticide_Use_Category', 'Number_Doses_Week', 'Number_Weeks_Used',
#        'Number_Weeks_Quit', 'Season'],
#       dtype='object')

# %%
df_train.dtypes
# Out:
# ID                          object
# Estimated_Insects_Count      int64
# Crop_Type                    int64
# Soil_Type                    int64
# Pesticide_Use_Category       int64
# Number_Doses_Week            int64
# Number_Weeks_Used          float64
# Number_Weeks_Quit            int64
# Season                       int64
# dtype: object

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   ID                       1199 non-null   object
#  1   Estimated_Insects_Count  1199 non-null   int64
#  2   Crop_Type                1199 non-null   int64
#  3   Soil_Type                1199 non-null   int64
#  4   Pesticide_Use_Category   1199 non-null   int64
#  5   Number_Doses_Week        1199 non-null   int64
#  6   Number_Weeks_Used        1080 non-null   float64
#  7   Number_Weeks_Quit        1199 non-null   int64
#  8   Season                   1199 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 84.4+ KB

# %%
df_train.describe()
# Out:
#        Estimated_Insects_Count    Crop_Type    Soil_Type  \
# count              1199.000000  1199.000000  1199.000000
# mean               1288.737281     0.194329     0.455379
# std                 845.004912     0.395848     0.498213
# min                 150.000000     0.000000     0.000000
# 25%                 677.000000     0.000000     0.000000
# 50%                1056.000000     0.000000     0.000000
# 75%                1785.000000     0.000000     1.000000
# max                4097.000000     1.000000     1.000000
#
#        Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# count             1199.000000        1199.000000        1080.000000
# mean                 2.383653          26.555463          29.033333
# std                  0.522866          16.154101          12.782083
# min                  1.000000           0.000000           0.000000
# 25%                  2.000000          15.000000          20.000000
# ...

# %%
#lets check whether the null values are present in the dataset or not using heatmap
sns.heatmap(df_train.isnull(),annot=True)
plt.show()

# %%
#Lets check the null values without using visualization
df_train.isnull().sum()
# Out:
# ID                           0
# Estimated_Insects_Count      0
# Crop_Type                    0
# Soil_Type                    0
# Pesticide_Use_Category       0
# Number_Doses_Week            0
# Number_Weeks_Used          119
# Number_Weeks_Quit            0
# Season                       0
# dtype: int64

# %%
df_train.plot(kind='box',subplots=True,layout=(5,6))
# Out:
# Estimated_Insects_Count       AxesSubplot(0.125,0.749828;0.110714x0.130172)
# Crop_Type                  AxesSubplot(0.257857,0.749828;0.110714x0.130172)
# Soil_Type                  AxesSubplot(0.390714,0.749828;0.110714x0.130172)
# Pesticide_Use_Category     AxesSubplot(0.523571,0.749828;0.110714x0.130172)
# Number_Doses_Week          AxesSubplot(0.656429,0.749828;0.110714x0.130172)
# Number_Weeks_Used          AxesSubplot(0.789286,0.749828;0.110714x0.130172)
# Number_Weeks_Quit             AxesSubplot(0.125,0.593621;0.110714x0.130172)
# Season                     AxesSubplot(0.257857,0.593621;0.110714x0.130172)
# dtype: object

# %%
df_train.hist(figsize=(15,15))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000020DE71D3148>,
# ...
#       dtype=object)

# %%
sns.pairplot(df_train)

# %%
#Lets check the correlation matrix
df_train.corr()
# Out:
#                          Estimated_Insects_Count  Crop_Type  Soil_Type  \
# Estimated_Insects_Count                 1.000000   0.020773  -0.339516
# Crop_Type                               0.020773   1.000000   0.063050
# Soil_Type                              -0.339516   0.063050   1.000000
# Pesticide_Use_Category                  0.038259   0.482378   0.129857
# Number_Doses_Week                      -0.121168  -0.170014   0.057118
# Number_Weeks_Used                       0.521308   0.065865  -0.146997
# Number_Weeks_Quit                       0.146441  -0.390935  -0.191989
# Season                                  0.023384   0.020282  -0.069242
#
#                          Pesticide_Use_Category  Number_Doses_Week  \
# Estimated_Insects_Count                0.038259          -0.121168
# Crop_Type                              0.482378          -0.170014
# Soil_Type                              0.129857           0.057118
# ...

# %%
sns.heatmap(df_train.corr(),annot=True)

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_train.corr(),cmap='Blues',annot=True)

# %%
#Lets describe the matrix
df_train.describe()
# Out:
#        Estimated_Insects_Count    Crop_Type    Soil_Type  \
# count              1199.000000  1199.000000  1199.000000
# mean               1288.737281     0.194329     0.455379
# std                 845.004912     0.395848     0.498213
# min                 150.000000     0.000000     0.000000
# 25%                 677.000000     0.000000     0.000000
# 50%                1056.000000     0.000000     0.000000
# 75%                1785.000000     0.000000     1.000000
# max                4097.000000     1.000000     1.000000
#
#        Pesticide_Use_Category  Number_Doses_Week  Number_Weeks_Used  \
# count             1199.000000        1199.000000        1080.000000
# mean                 2.383653          26.555463          29.033333
# std                  0.522866          16.154101          12.782083
# min                  1.000000           0.000000           0.000000
# 25%                  2.000000          15.000000          20.000000
# ...

# %%
#Lets check the skewness of the dataset
df_train.skew()
#there is some skewness which needs to be treated ,by seeing we can say obly +ve skewness is signifiacnt and needs to be treated
# Out:
# Estimated_Insects_Count    1.098665
# Crop_Type                  1.546968
# Soil_Type                  0.179422
# Pesticide_Use_Category     0.089675
# Number_Doses_Week          0.872028
# Number_Weeks_Used          0.209152
# Number_Weeks_Quit          1.191013
# Season                     0.155872
# dtype: float64
